# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresMontesDeOca/Machine_Learning/blob/main/F1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Configura para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# Configura para mostrar todas las filas
# (Ten cuidado si el dataset es muy grande, podría tildar la pestaña)
pd.set_option('display.max_rows', None)

# Opcional: configurar el ancho de las columnas para que no se corte el texto
pd.set_option('display.max_colwidth', None)

# %%
import kagglehub

# Download latest version
path = kagglehub.competition_download('playground-series-s6e5')

print("Path to competition files:", path)
# Out:
# Path to competition files: /root/.cache/kagglehub/competitions/playground-series-s6e5

# %%
path
# Out:
# '/root/.cache/kagglehub/competitions/playground-series-s6e5'

# %%
# The path to the downloaded competition files is stored in the 'path' variable
print(f"Listing files in: {path}")
files = os.listdir(path)
print(files)

# Assuming there are CSV files like 'train.csv' and 'test.csv'
# We'll load them if they exist

try:
    data = pd.read_csv(os.path.join(path, 'train.csv'))
    print("Train DataFrame loaded successfully:")
    # print(train_df.head())
    print(f"Train DataFrame shape: {data.shape}")
except FileNotFoundError:
    print("train.csv not found in the specified path.")

try:
    test = pd.read_csv(os.path.join(path, 'test.csv'))
    print("\nTest DataFrame loaded successfully:")
    # print(test.head())
    print(f"Test DataFrame shape: {test.shape}")
except FileNotFoundError:
    print("test.csv not found in the specified path.")

# You can modify the above to load other files as needed.
# Out:
# Listing files in: /root/.cache/kagglehub/competitions/playground-series-s6e5
# ['test.csv', 'sample_submission.csv', 'train.csv']
# Train DataFrame loaded successfully:
# Train DataFrame shape: (439140, 16)
#
# Test DataFrame loaded successfully:
# Test DataFrame shape: (188165, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439140 entries, 0 to 439139
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      439140 non-null  int64
#  1   Driver                  439140 non-null  object
#  2   Compound                439140 non-null  object
#  3   Race                    439140 non-null  object
#  4   Year                    439140 non-null  int64
#  5   PitStop                 439140 non-null  int64
#  6   LapNumber               439140 non-null  int64
#  7   Stint                   439140 non-null  int64
#  8   TyreLife                439140 non-null  float64
#  9   Position                439140 non-null  int64
#  10  LapTime (s)             439140 non-null  float64
#  11  LapTime_Delta           439140 non-null  float64
#  12  Cumulative_Degradation  439140 non-null  float64
#  13  RaceProgress            439140 non-null  float64
# ...

# %%
data.sample(5)
# Out:
#             id Driver Compound                    Race  Year  PitStop  \
# 170064  170064    FER   MEDIUM   Australian Grand Prix  2022        0
# 315731  315731   D005   MEDIUM  Mexico City Grand Prix  2022        0
# 88778    88778   D045   MEDIUM      British Grand Prix  2023        0
# 426661  426661    VAN   MEDIUM        Miami Grand Prix  2024        0
# 372510  372510   D134     HARD     Austrian Grand Prix  2023        0
#
#         LapNumber  Stint  TyreLife  Position  LapTime (s)  LapTime_Delta  \
# 170064         19      1      19.0         4       85.593        -26.264
# 315731          2      1       2.0         5       85.948        -19.203
# 88778          18      1      18.0         7       93.732         -0.235
# 426661          1      1       2.0        11       97.842         -5.792
# 372510         17      3       6.0        14       70.753         -0.004
#
#         Cumulative_Degradation  RaceProgress  Position_Change  PitNextLap
# ...

# %%
pd.crosstab(data['Year'], data['Race'])
# Out:
# Race  Abu Dhabi Grand Prix  Australian Grand Prix  Austrian Grand Prix  \
# Year
# 2022                    56                   5333                 4534
# 2023                  7784                   4879                 5695
# 2024                  4705                   5661                 6671
# 2025                  3882                   2533                 4323
#
# Race  Azerbaijan Grand Prix  Bahrain Grand Prix  Belgian Grand Prix  \
# Year
# 2022                   2564                4034                1837
# 2023                   5099                6700                2922
# 2024                   2597                5405                2691
# 2025                   1866                3396                1552
#
# Race  British Grand Prix  Canadian Grand Prix  Chinese Grand Prix  \
# Year
# 2022                2532                 5016                   8
# 2023                7633                 6063                  17
# ...

# %%
mask_2025 = data["Year"] == 2025
mask_dutch = data["Race"] == "Dutch Grand Prix"

data = data[mask_2025 & mask_dutch]


data
# Out:
#             id Driver Compound              Race  Year  PitStop  LapNumber  \
# 1            1   D086     HARD  Dutch Grand Prix  2025        1         27
# 48          48   D101     HARD  Dutch Grand Prix  2025        0         51
# 60          60   D293     HARD  Dutch Grand Prix  2025        0         41
# 154        154    ZON   MEDIUM  Dutch Grand Prix  2025        0          7
# 223        223   D058     SOFT  Dutch Grand Prix  2025        0         64
# ...        ...    ...      ...               ...   ...      ...        ...
# 438884  438884   D226   MEDIUM  Dutch Grand Prix  2025        0         13
# 438906  438906   D080     SOFT  Dutch Grand Prix  2025        1         56
# 439023  439023   D105   MEDIUM  Dutch Grand Prix  2025        0          9
# 439089  439089   D356   MEDIUM  Dutch Grand Prix  2025        0         12
# 439112  439112   D106     HARD  Dutch Grand Prix  2025        0         44
#
#         Stint  TyreLife  Position  LapTime (s)  LapTime_Delta  \
# ...

# %%
data["Driver"].describe()
# Out:
# count     6416
# unique     526
# top        OCO
# freq        27
# Name: Driver, dtype: object
